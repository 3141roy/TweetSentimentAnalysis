# %%
import re
import numpy as np
import pandas as pd
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.stem import PorterStemmer
from nltk.corpus import wordnet

# %% [markdown]
# The dataset used here has 10980 tweets for training and 3660 tweets for testing

# %%
train = pd.read_csv('0000000000002747_training_twitter_x_y_train.csv')
test  = pd.read_csv('0000000000002747_test_twitter_x_test.csv')

# %%
train.head()
# Out:
#              tweet_id airline_sentiment    airline airline_sentiment_gold  \
# 0  567900433542488064          negative  Southwest                    NaN
# 1  569989168903819264          positive  Southwest                    NaN
# 2  568089179520954368          positive     United                    NaN
# 3  568928195581513728          negative  Southwest                    NaN
# 4  568594180014014464          negative     United                    NaN
#
#             name negativereason_gold  retweet_count  \
# 0  ColeyGirouard                 NaN              0
# 1  WalterFaddoul                 NaN              0
# 2      LocalKyle                 NaN              0
# 3    amccarthy19                 NaN              0
# 4        J_Okayy                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @SouthwestAir I am scheduled for the morning, ...         NaN
# 1  @SouthwestAir seeing your workers time in and ...         NaN
# 2  @united Flew ORD to Miami and back and  had gr...         NaN
# 3     @SouthwestAir @dultch97 that's horse radish 😤🐴         NaN
# 4  @united so our flight into ORD was delayed bec...         NaN
#
#                tweet_created              tweet_location  \
# 0  2015-02-17 20:16:29 -0800             Washington D.C.
# 1  2015-02-23 14:36:22 -0800  Indianapolis, Indiana; USA
# 2  2015-02-18 08:46:29 -0800                    Illinois
# 3  2015-02-20 16:20:26 -0800                         NaN
# 4  2015-02-19 18:13:11 -0800                         NaN
#
#                 user_timezone
# 0      Atlantic Time (Canada)
# 1  Central Time (US & Canada)
# 2  Central Time (US & Canada)
# 3      Atlantic Time (Canada)
# 4  Eastern Time (US & Canada)

# %%
test.head()
# Out:
#              tweet_id     airline airline_sentiment_gold          name  \
# 0  569682010270101504    American                    NaN      zsalim03
# 1  569608307184242688    American                    NaN      sa_craig
# 2  567879304593408001   Southwest                    NaN  DanaChristos
# 3  569757651539660801  US Airways                    NaN      rossj987
# 4  569900705852608513    American                    NaN    tranpham18
#
#   negativereason_gold  retweet_count  \
# 0                 NaN              0
# 1                 NaN              0
# 2                 NaN              1
# 3                 NaN              0
# 4                 NaN              0
#
#                                                 text tweet_coord  \
# 0  @AmericanAir In car gng to DFW. Pulled over 1h...         NaN
# 1  @AmericanAir after all, the plane didn’t land ...         NaN
# 2  @SouthwestAir can't believe how many paying cu...         NaN
# 3  @USAirways I can legitimately say that I would...         NaN
# 4  @AmericanAir still no response from AA. great ...         NaN
#
#                tweet_created       tweet_location               user_timezone
# 0  2015-02-22 18:15:50 -0800                Texas  Central Time (US & Canada)
# 1  2015-02-22 13:22:57 -0800  College Station, TX  Central Time (US & Canada)
# 2  2015-02-17 18:52:31 -0800                   CT  Eastern Time (US & Canada)
# 3  2015-02-22 23:16:24 -0800     Washington, D.C.  Eastern Time (US & Canada)
# 4  2015-02-23 08:44:51 -0800        New York City  Eastern Time (US & Canada)

# %%
#Making a collection for stopwords and punctuations for cleaning the tweets

stop = stopwords.words('english')
punc = list(string.punctuation)
stop = stop+punc

# %% [markdown]
# I tried different techniques to clean the tweets with Stemming (PorterStemmer, SnowballStemmer) and Lemmatization but in the end used Lemmatization because it gave better accuracy

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
from nltk.stem.snowball import SnowballStemmer
ss = SnowballStemmer(language='english')

# %% [markdown]
# PyEnchant was used as it provides a set of Python language bindings for the Enchant spellchecking library and is used to remove certain words that had spelling mistakes or were not words of the english dictionary

# %%
import enchant
d = enchant.Dict("en_US")

# %% [markdown]
# Now we extract the required parts of the data from the given datasets that will be required to train the model

# %%
train_data = np.array(train['text'])
test_data  = np.array(test['text'])

y_train = np.array(train['airline_sentiment'])

# %% [markdown]
# Now we clean the tweets by using Lemmatization techniques and using regular expressions to remove links. We also filter out the stopwords and punctuations

# %%
### Cleaning the tweets

def partOfSpeech(pos):
    if pos.startswith('J'):
        return wordnet.ADJ
    elif pos.startswith('V'):
        return wordnet.VERB
    elif pos.startswith('N'):
        return wordnet.NOUN
    elif pos.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    

lemmatizer = WordNetLemmatizer()
def tweetModifier(tweet):

    tweet = tweet.lower()
    tweet = re.sub(r'^https?:\/\/.*[\r\n]*', '', tweet, flags=re.MULTILINE)
    
    pos_tweet = pos_tag(word_tokenize(tweet)) 
    m_tweets = list(map(lambda x: (x[0], partOfSpeech(x[1])), pos_tweet))
    
    m_tweet = []
    
    for i, tag in m_tweets:
        if i not in stop and d.check(i) and i.isalpha():
            cleaned = lemmatizer.lemmatize(i, tag)
            #cleaned = ss.stem(i)
            if(len(cleaned)>1 and d.check(cleaned)):
                m_tweet.append(cleaned)

    return m_tweet #returns the modified tweet

# %%
train_data=[(tweetModifier(tweet)) for tweet in train_data]
test_data=[(tweetModifier(tweet)) for tweet in test_data]

# %%
train_data
# Out:
# [['schedule',
#   'morning',
#   'day',
#   'fact',
#   'yes',
#   'sure',
#   'evening',
#   'flight',
#   'one',
#   'cancel'],
#  ['see',
#   'worker',
#   'time',
#   'time',
#   'go',
#   'beyond',
#   'love',
#   'fly',
#   'guy',
#   'thank'],
#  ['united', 'fly', 'ord', 'back', 'great', 'crew', 'service', 'leg', 'thanks'],
#  ['horse', 'radish'],
#  ['unite',
#   'flight',
#   'ord',
#   'delay',
#   'air',
#   'force',
#   'one',
#   'last',
#   'flight',
#   'land'],
#  ['united',
#   'load',
#   'fly',
#   'sardine',
#   'know',
#   'pilot',
#   'hour',
#   'late',
#   'flight',
#   'incompetent',
#   'beyond',
#   'belief'],
#  ['stock',
#   'response',
#   'delay',
#   'frustrating',
#   'poor',
#   'amp',
#   'tell',
#   'wait',
#   'amp',
#   'come',
#   'back'],
#  ['nice',
#   'hop',
#   'rack',
#   'enough',
#   'mile',
#   'take',
#   'trip',
#   'enjoy',
#   'perfect',
#   'latte',
#   'city',
#   'coffee'],
#  ['united',
#   'frankly',
#   'bad',
#   'customer',
#   'service',
#   'ever',
#   'problem',
#   'happen',
#   'deal',
#   'define',
#   'company',
#   'never',
#   'united'],
#  ['yeah', 'never', 'one', 'expensive', 'much', 'fun'],
#  ['gt',
#   'flight',
#   'almost',
#   'full',
#   'people',
#   'screw',
#   'cancel',
#   'united',
#   'cancel',
#   'flight'],
#  ['easy',
#   'way',
#   'get',
#   'ticket',
#   'receipt',
#   'get',
#   'one',
#   'check',
#   'get',
#   'one',
#   'online',
#   'thanks'],
#  ['love',
#   'change',
#   'lounge',
#   'cheese',
#   'veggie',
#   'olive',
#   'addition',
#   'cracker',
#   'snack',
#   'mix'],
#  ['receive',
#   'bad',
#   'customer',
#   'service',
#   'end',
#   'spending',
#   'several',
#   'hundred',
#   'dollar',
#   'accommodate',
#   'family',
#   'flight'],
#  ['kill',
#   'flight',
#   'board',
#   'min',
#   'mine',
#   'arrive',
#   'gate',
#   'side',
#   'airport'],
#  ['week',
#   'refund',
#   'ticket',
#   'totally',
#   'unacceptable',
#   'fix',
#   'put',
#   'blast',
#   'social',
#   'medium'],
#  ['private',
#   'provide',
#   'detail',
#   'really',
#   'need',
#   'customer',
#   'training',
#   'staff'],
#  ['rt', 'fleet'],
#  ['info', 'flight', 'already', 'delay', 'hour'],
#  ['try',
#   'less',
#   'time',
#   'today',
#   'get',
#   'touch',
#   'service',
#   'desk',
#   'begin',
#   'est',
#   'luck'],
#  ['new',
#   'problem',
#   'wrong',
#   'last',
#   'name',
#   'reservation',
#   'airways',
#   'fix',
#   'new',
#   'ca',
#   'get'],
#  ['possible',
#   'chance',
#   'bring',
#   'back',
#   'service',
#   'would',
#   'make',
#   'much',
#   'easy',
#   'connect',
#   'west',
#   'coast'],
#  ['run',
#   'show',
#   'airport',
#   'boarding',
#   'pas',
#   'say',
#   'airway',
#   'wait',
#   'line'],
#  ['united',
#   'computer',
#   'stop',
#   'give',
#   'update',
#   'take',
#   'flight',
#   'info',
#   'app',
#   'ridiculous',
#   'keep',
#   'people',
#   'update'],
#  ['united', 'good', 'fly', 'united'],
#  ['unite', 'fly', 'child', 'turn', 'trip', 'buy', 'return', 'ticket', 'child'],
#  ['love', 'cancel', 'ticket', 'tell', 'customer'],
#  ['unite',
#   'ord',
#   'wait',
#   'min',
#   'crew',
#   'member',
#   'leave',
#   'gate',
#   'item',
#   'come',
#   'flight',
#   'attendant',
#   'sarcastically',
#   'say',
#   'good',
#   'luck',
#   'walk',
#   'away'],
#  ['gate', 'make', 'afternoon', 'thanks'],
#  ['everything', 'sort', 'thanks', 'help', 'excite', 'get', 'home', 'tonight'],
#  ['understand',
#   'weather',
#   'would',
#   'nice',
#   'hear',
#   'apology',
#   'phone',
#   'move',
#   'flight',
#   'inconvenient',
#   'day'],
#  ['thanks'],
#  ['unite', 'book', 'first', 'class', 'curbside', 'delivery', 'hour', 'count'],
#  ['oh',
#   'totally',
#   'look',
#   'par',
#   'admiral',
#   'club',
#   'way',
#   'slide',
#   'couple',
#   'pass'],
#  ['official',
#   'complaint',
#   'sign',
#   'supervisor',
#   'customer',
#   'relation',
#   'compensate',
#   'delay'],
#  ['hour',
#   'call',
#   'say',
#   'report',
#   'soon',
#   'enough',
#   'would',
#   'change',
#   'notice',
#   'sooner'],
#  ['unite',
#   'frustrating',
#   'fly',
#   'experience',
#   'one',
#   'continuous',
#   'dunno',
#   'time',
#   'leave',
#   'today',
#   'dunno',
#   'code'],
#  ['hi',
#   'get',
#   'message',
#   'part',
#   'flight',
#   'cancel',
#   'ca',
#   'rebook',
#   'online',
#   'nobody',
#   'answer',
#   'phone',
#   'call',
#   'help'],
#  ['need', 'update', 'flight', 'amp', 'hold', 'hour'],
#  ['suppose', 'fly', 'help', 'get', 'new', 'itinerary'],
#  ['fail', 'flight', 'sit', 'wait', 'flight', 'attendant', 'logistics', 'good'],
#  ['unite', 'impressed', 'reply'],
#  ['united',
#   'speak',
#   'baggage',
#   'contact',
#   'number',
#   'say',
#   'try',
#   'get',
#   'bag',
#   'stay',
#   'pick'],
#  ['intentionally',
#   'buy',
#   'flight',
#   'hour',
#   'layover',
#   'kind',
#   'airline',
#   'would',
#   'charge',
#   'fix',
#   'wow'],
#  ['auto', 'callback', 'wait', 'hold'],
#  ['united', 'get', 'service', 'desk'],
#  ['blue', 'help', 'bring', 'color', 'eye', 'promise', 'eat', 'free', 'snack'],
#  ['united', 'yes'],
#  ['report',
#   'updated',
#   'info',
#   'know',
#   'reach',
#   'without',
#   'super',
#   'long',
#   'wait',
#   'hold',
#   'main',
#   'number'],
#  ['want',
#   'enter',
#   'family',
#   'pool',
#   'contest',
#   'say',
#   'website',
#   'please',
#   'enter',
#   'still'],
#  ['choose', 'seat', 'free', 'click', 'button'],
#  ['united', 'plus', 'food', 'taxis'],
#  ['right', 'end', 'sight'],
#  ['really', 'go', 'let', 'delta', 'get', 'best'],
#  ['claim',
#   'flight',
#   'cancel',
#   'flight',
#   'due',
#   'weather',
#   'destination',
#   'delta',
#   'cancel',
#   'flight',
#   'flight',
#   'route'],
#  ['thanks', 'much', 'help', 'amazing'],
#  ['say', 'fault', 'somehow', 'guy', 'joke'],
#  ['customer',
#   'service',
#   'inferior',
#   'nationalized',
#   'third',
#   'world',
#   'nation',
#   'airline',
#   'get',
#   'together'],
#  ['app', 'sort', 'notification', 'option'],
#  ['united', 'thank'],
#  ['try',
#   'reach',
#   'customer',
#   'service',
#   'two',
#   'day',
#   'receive',
#   'zero',
#   'response',
#   'never',
#   'travel',
#   'aa'],
#  ['united',
#   'flight',
#   'agent',
#   'wander',
#   'pilot',
#   'come',
#   'look',
#   'go',
#   'charge',
#   'personal',
#   'phone'],
#  ['unite',
#   'first',
#   'lose',
#   'bag',
#   'cancel',
#   'flight',
#   'flight',
#   'home',
#   'min',
#   'wait',
#   'talk',
#   'somebody'],
#  ['sit', 'plane', 'hr', 'finally', 'take'],
#  ['anywhere'],
#  ['spend',
#   'cost',
#   'flight',
#   'get',
#   'free',
#   'room',
#   'transportation',
#   'airport'],
#  ['understand',
#   'weather',
#   'kid',
#   'need',
#   'get',
#   'home',
#   'nice',
#   'kid',
#   'volunteer',
#   'work',
#   'high',
#   'school',
#   'please',
#   'help'],
#  ['friend', 'need', 'help', 'flt', 'dm', 'info'],
#  ['mom',
#   'flight',
#   'tomorrow',
#   'cancel',
#   'flight',
#   'notice',
#   'phone',
#   'system',
#   'say',
#   'callback',
#   'hour',
#   'need',
#   'go',
#   'bed'],
#  ['flight',
#   'veers',
#   'icy',
#   'runway',
#   'flight',
#   'cancel',
#   'flighted',
#   'mon',
#   'figure',
#   'right'],
#  ['unite',
#   'could',
#   'tell',
#   'bag',
#   'would',
#   'accept',
#   'personal',
#   'item',
#   'bring',
#   'one',
#   'bag',
#   'plus'],
#  ['united', 'yo', 'need', 'new', 'website', 'really', 'badly', 'day', 'age'],
#  ['great', 'first', 'night'],
#  ['right', 'amp', 'away'],
#  ['unite',
#   'two',
#   'dozen',
#   'back',
#   'line',
#   'see',
#   'single',
#   'book',
#   'problem',
#   'final',
#   'leg',
#   'kiosk',
#   'fritz'],
#  ['would', 'charge', 'money', 'transfer', 'point', 'someone'],
#  ['possible',
#   'earn',
#   'dividend',
#   'mile',
#   'passenger',
#   'even',
#   'purchase',
#   'ticket'],
#  ['fleet'],
#  ['phone',
#   'line',
#   'call',
#   'affect',
#   'bad',
#   'weather',
#   'try',
#   'book',
#   'vacation'],
#  ['never',
#   'see',
#   'incompetency',
#   'gate',
#   'agent',
#   'year',
#   'business',
#   'travel',
#   'gate',
#   'agent',
#   'need',
#   'training',
#   'new',
#   'job'],
#  ['den',
#   'impressive',
#   'lack',
#   'concern',
#   'late',
#   'flight',
#   'flight',
#   'wreck',
#   'havoc',
#   'customer',
#   'travel'],
#  ['unite',
#   'client',
#   'hr',
#   'layover',
#   'day',
#   'claim',
#   'amp',
#   'recheck',
#   'luggage',
#   'take',
#   'care'],
#  ['unite',
#   'even',
#   'change',
#   'could',
#   'make',
#   'instructed',
#   'call',
#   'maybe',
#   'allow',
#   'agent',
#   'link',
#   'passenger'],
#  ['unite',
#   'ca',
#   'claim',
#   'weather',
#   'hardworking',
#   'crew',
#   'pull',
#   'seat',
#   'plane',
#   'right',
#   'thing',
#   'know',
#   'wo'],
#  ['finally', 'call', 'ca', 'get', 'met', 'refund', 'process', 'thanks'],
#  ['united', 'play', 'bizarre', 'safety', 'video', 'ever', 'see'],
#  ['sure', 'messaging', 'part', 'right', 'please', 'let', 'know', 'receive'],
#  ['book', 'save', 'emergency', 'exit', 'get', 'ta', 'stretch'],
#  ['try',
#   'get',
#   'customer',
#   'destination',
#   'help',
#   'get',
#   'another',
#   'airline',
#   'flight',
#   'day'],
#  ['catch', 'name', 'sure', 'know'],
#  ['yet', 'another', 'connection', 'customer', 'service', 'attitude', 'wow'],
#  ['access',
#   'dividend',
#   'mile',
#   'week',
#   'automate',
#   'phone',
#   'keep',
#   'tell',
#   'call',
#   'back',
#   'late',
#   'frustrated'],
#  ['united', 'direct', 'flight', 'resume', 'winter', 'break', 'thanks'],
#  ['united',
#   'voluntarily',
#   'rerouted',
#   'leg',
#   'journey',
#   'economy',
#   'suppose',
#   're',
#   'agent',
#   'say',
#   'reserve'],
#  ['airport',
#   'runways',
#   'open',
#   'appear',
#   'southwest',
#   'airline',
#   'cancel',
#   'flight',
#   'likely',
#   'change'],
#  ['flight', 'plan', 'delay', 'due', 'computer', 'crash'],
#  ['unbelievable', 'thank', 'much'],
#  ['united',
#   'big',
#   'surprise',
#   'waiting',
#   'plane',
#   'issue',
#   'everything',
#   'fly',
#   'fail'],
#  ['tough',
#   'night',
#   'two',
#   'minute',
#   'call',
#   'hold',
#   'delay',
#   'phoenix',
#   'two',
#   'day',
#   'one',
#   'aircraft',
#   'ready',
#   'acceptable'],
#  ['unite',
#   'hard',
#   'stay',
#   'upset',
#   'someone',
#   'least',
#   'try',
#   'show',
#   'remorse'],
#  ['united',
#   'min',
#   'hold',
#   'try',
#   'book',
#   'award',
#   'flight',
#   'site',
#   'error',
#   'agent',
#   'ask',
#   'pin',
#   'see',
#   'platinum',
#   'availability'],
#  ['min', 'hold', 'drive', 'hour', 'get', 'delay', 'bag', 'want', 'pick'],
#  ['reserve', 'seat', 'aa', 'flight', 'transfer', 'ord'],
#  ['united', 'start', 'flight'],
#  ['united', 'flight', 'hour', 'pretzel', 'peanut', 'seriously', 'pass'],
#  ['unite', 'leave', 'comment', 'customer', 'care', 'thanks', 'contact'],
#  ['united', 'hold', 'plane', 'make'],
#  ['may',
#   'keep',
#   'lose',
#   'bag',
#   'info',
#   'longer',
#   'trust',
#   'bad',
#   'way',
#   'handle'],
#  [],
#  ['learn',
#   'awesome',
#   'twitter',
#   'management',
#   'today',
#   'social',
#   'medium',
#   'market',
#   'class',
#   'keep',
#   'good',
#   'work'],
#  ['drop',
#   'ball',
#   'catering',
#   'plane',
#   'switch',
#   'gate',
#   'attendant',
#   'hour',
#   'late',
#   'flight',
#   'really',
#   'nice'],
#  ['good',
#   'care',
#   'customer',
#   'anything',
#   'happen',
#   'take',
#   'delta',
#   'get',
#   'back',
#   'screw'],
#  ['think',
#   'help',
#   'base',
#   'behavior',
#   'voucher',
#   'cot',
#   'seem',
#   'like',
#   'enough'],
#  ['unite',
#   'think',
#   'problem',
#   'resolution',
#   'decide',
#   'end',
#   'especially',
#   'like',
#   'continue',
#   'fly',
#   'airline'],
#  ['hold',
#   'count',
#   'cause',
#   'charge',
#   'credit',
#   'card',
#   'bag',
#   'provide',
#   'receipt',
#   'say',
#   'error',
#   'awful'],
#  ['united', 'great', 'look', 'forward', 'response', 'dm'],
#  ['unite',
#   'birthday',
#   'sister',
#   'come',
#   'celebrate',
#   'flight',
#   'keep',
#   'cancel',
#   'get'],
#  ['employee',
#   'name',
#   'van',
#   'ticket',
#   'counter',
#   'extremely',
#   'rude',
#   'father',
#   'try',
#   'get',
#   'home',
#   'sick',
#   'kid',
#   'missed',
#   'flight'],
#  ['horrible',
#   'experience',
#   'ever',
#   'airline',
#   'reconsider',
#   'future',
#   'flight',
#   'customer',
#   'service'],
#  ['tomorrow', 'site', 'show', 'flight', 'cancel'],
#  ['like',
#   'customer',
#   'service',
#   'min',
#   'delay',
#   'connect',
#   'passenger',
#   'seem',
#   'long'],
#  ['cutest',
#   'salt',
#   'pepper',
#   'shaker',
#   'ever',
#   'think',
#   'guy',
#   'ca',
#   'get',
#   'good'],
#  ['unbelievable',
#   'even',
#   'wait',
#   'hold',
#   'speak',
#   'human',
#   'resolve',
#   'issue',
#   'system',
#   'simply',
#   'hang'],
#  ['continue',
#   'win',
#   'never',
#   'miss',
#   'flight',
#   'nice',
#   'little',
#   'quiet',
#   'gate',
#   'change',
#   'make',
#   'possible'],
#  ['even',
#   'offer',
#   'fly',
#   'another',
#   'airport',
#   'say',
#   'could',
#   'explanation',
#   'ca'],
#  ['phone',
#   'number',
#   'gate',
#   'give',
#   'work',
#   'either',
#   'customer',
#   'service',
#   'phone',
#   'number'],
#  ['flight'],
#  ['yes',
#   'still',
#   'human',
#   'hope',
#   'deal',
#   'horror',
#   'stories',
#   'people',
#   'share',
#   'complain',
#   'dot',
#   'everyone'],
#  ['send', 'plane', 'anyone', 'clue'],
#  ['winner'],
#  ['united',
#   'quick',
#   'serious',
#   'question',
#   'show',
#   'quality',
#   'service',
#   'good',
#   'place'],
#  ['united', 'get', 'first', 'flight', 'day', 'ground', 'time', 'let', 'go'],
#  ['southwest', 'mobile', 'board', 'pass', 'available', 'passbook'],
#  ['stick', 'fort'],
#  ['clear', 'folder', 'regularly', 'white', 'list', 'never', 'get'],
#  ['united',
#   'keep',
#   'flight',
#   'cheap',
#   'time',
#   'good',
#   'flew',
#   'cancel',
#   'flight',
#   'time',
#   'last',
#   'month',
#   'united',
#   'gt'],
#  ['believe',
#   'super',
#   'disappoint',
#   'cafe',
#   'available',
#   'gt',
#   'flight',
#   'today'],
#  ['flight', 'place', 'original', 'flight', 'charlotte', 'cancel', 'delay'],
#  ['captain',
#   'turn',
#   'seat',
#   'belt',
#   'sign',
#   'people',
#   'get',
#   'walk',
#   'around',
#   'good'],
#  ['unite', 'flight', 'go', 'get', 'plane'],
#  ['call',
#   'chairman',
#   'call',
#   'emerald',
#   'today',
#   'call',
#   'former',
#   'customer'],
#  ['saw', 'one', 'useless', 'agent', 'inspect', 'shoe'],
#  ['united', 'thank', 'response'],
#  ['one',
#   'receive',
#   'text',
#   'alert',
#   'automate',
#   'call',
#   'anything',
#   'either',
#   'literally',
#   'information',
#   'happen'],
#  ['make', 'send', 'bloody', 'row'],
#  ['united',
#   'gate',
#   'change',
#   'two',
#   'delay',
#   'even',
#   'crew',
#   'think',
#   'airline',
#   'suck'],
#  ['thank', 'empathy', 'story', 'luggage', 'thank', 'reach'],
#  ['thanks',
#   'actually',
#   'birder',
#   'love',
#   'need',
#   'outside',
#   'hard',
#   'trap',
#   'move'],
#  ['flt', 'day', 'suppose', 'depart', 'still', 'crew', 'pilot'],
#  ['allow', 'payment', 'apple', 'pay'],
#  ['united', 'rep', 'hang', 'hold', 'ask', 'supervisor', 'furious', 'right'],
#  ['try',
#   'book',
#   'past',
#   'need',
#   'arrive',
#   'still',
#   'sell',
#   'seat',
#   'day',
#   'try',
#   'travel'],
#  ['seriously', 'service', 'issue', 'right', 'decide', 'tweet', 'unbelievable'],
#  ['also', 'pass', 'website', 'around', 'passenger'],
#  ['united', 'click', 'link', 'get', 'confused'],
#  ['well',
#   'clear',
#   'custom',
#   'need',
#   'get',
#   'arrive',
#   'possible',
#   'retrieve',
#   'luggage'],
#  ['get', 'ta', 'love', 'responsiveness', 'least', 'huh'],
#  ['flight',
#   'cancel',
#   'ca',
#   'get',
#   'desk',
#   'nothing',
#   'show',
#   'online',
#   'reservation'],
#  ['pregnant',
#   'twin',
#   'go',
#   'abandon',
#   'overnight',
#   'airport',
#   'hotel',
#   'fault'],
#  ['united',
#   'thanks',
#   'prompt',
#   'response',
#   'another',
#   'hour',
#   'enjoy',
#   'vacation',
#   'perhaps',
#   'bug',
#   'app',
#   'still',
#   'show'],
#  ['united', 'try', 'figure', 'go', 'get'],
#  ['united', 'except', 'delay', 'flight', 'anyway'],
#  ['get', 'flight', 'air'],
#  ['united', 'let', 'assure', 'travel', 'time', 'timezones'],
#  ['unite', 'thanks', 'catch'],
#  ['fleet'],
#  ['flight', 'artisanal', 'cheese', 'wine', 'pairing'],
#  ['united', 'flight', 'sit', 'tarmac', 'report', 'input'],
#  ['sits', 'throne', 'lie'],
#  ['flight', 'cancel', 'today', 'hold', 'hour'],
#  ['late', 'always', 'late', 'flight', 'please', 'get', 'back', 'old'],
#  ['pick', 'call', 'cancel', 'fail'],
#  ['would',
#   'anything',
#   'ticket',
#   'anything',
#   'love',
#   'imagine',
#   'dragon',
#   'much'],
#  ['thanks', 'attention', 'fly', 'southwest', 'year', 'issue', 'past'],
#  ['never', 'let', 'every', 'single', 'flight', 'get', 'delay'],
#  ['wife', 'fly', 'march', 'since', 'could', 'get', 'tn'],
#  ['united',
#   'flight',
#   'get',
#   'delayed',
#   'hour',
#   'due',
#   'mechanical',
#   'issue',
#   'could',
#   'use',
#   'free',
#   'drink',
#   'make',
#   'inconvenience'],
#  ['dream'],
#  ['line', 'airport', 'right', 'cover', 'hotel', 'fair', 'sleep', 'airport'],
#  ['one', 'would', 'tell', 'come', 'would', 'guess', 'change', 'flight'],
#  ['worry', 'swamp', 'know', 'back', 'thank'],
#  ['forget', 'put', 'number', 'check', 'profile', 'board', 'pas'],
#  ['five', 'people', 'show', 'yet'],
#  ['never', 'anything', 'bad', 'say', 'love', 'faithful', 'customer'],
#  ['hello', 'flight', 'take', 'airport', 'noon', 'suppose', 'travel', 'flight'],
#  ['love',
#   'appreciate',
#   'fact',
#   'guy',
#   'rarely',
#   'cancelled',
#   'flight',
#   'flight',
#   'time',
#   'need',
#   'cancelled',
#   'time'],
#  ['connection'],
#  ['unite', 'good', 'man', 'fault', 'plane', 'maintenance', 'issue'],
#  ['sensitive',
#   'fact',
#   'believe',
#   'warrant',
#   'poor',
#   'service',
#   'little',
#   'help',
#   'amp',
#   'compassion',
#   'go',
#   'long',
#   'way'],
#  ['online', 'resource', 'say', 'time', 'clearly', 'information', 'age'],
#  ['united',
#   'make',
#   'hard',
#   'fly',
#   'delay',
#   'hour',
#   'plane',
#   'turn',
#   'around',
#   'amp',
#   'head',
#   'back',
#   'gate',
#   'connection'],
#  ['people', 'kind', 'hardworking', 'infrastructure', 'give', 'horrid', 'fail'],
#  ['thanks', 'aviation', 'theme', 'surprise', 'party'],
#  ['airways', 'reveals', 'livery'],
#  ['bother', 'pick', 'phone', 'bad', 'customer', 'service', 'go'],
#  ['expect', 'delay', 'tomorrow', 'morning'],
#  ['flight',
#   'leave',
#   'even',
#   'begin',
#   'board',
#   'yet',
#   'please',
#   'update',
#   'website',
#   'asap'],
#  ['incredibly',
#   'arrogant',
#   'thing',
#   'say',
#   'sit',
#   'wait',
#   'incompetent',
#   'airline',
#   'refuel'],
#  ['airline',
#   'trouble',
#   'winter',
#   'amp',
#   'get',
#   'good',
#   'customer',
#   'service',
#   'contact',
#   'negotiate',
#   'resolution'],
#  ['united',
#   'thankful',
#   'great',
#   'service',
#   'seat',
#   'fix',
#   'seat',
#   'daughter',
#   'fab',
#   'land',
#   'fort'],
#  ['united',
#   'feeling',
#   'like',
#   'true',
#   'united',
#   'customer',
#   'tarmac',
#   'dc',
#   'hr'],
#  ['united', 'cool', 'customer', 'tell', 'care', 'either', 'expect'],
#  ['today',
#   'scavenger',
#   'hunt',
#   'start',
#   'try',
#   'help',
#   'little',
#   'brother',
#   'win'],
#  ['unite', 'shoddy', 'customer', 'service', 'use', 'whatsoever'],
#  ['option',
#   'luggage',
#   'assistance',
#   'ground',
#   'flight',
#   'delay',
#   'hour',
#   'amp',
#   'sleep',
#   'kid',
#   'land'],
#  ['dm'],
#  ['united',
#   'twice',
#   'case',
#   'id',
#   'number',
#   'assign',
#   'try',
#   'screen',
#   'say',
#   'thank',
#   'submit',
#   'request'],
#  ['guy',
#   'amazing',
#   'job',
#   'today',
#   'know',
#   'hard',
#   'thanks',
#   'hard',
#   'work',
#   'book',
#   'problem',
#   'friend'],
#  ['really',
#   'need',
#   'customer',
#   'service',
#   'train',
#   'unhappy',
#   'morning',
#   'gate'],
#  ['employee', 'great'],
#  ['aa',
#   'go',
#   'fix',
#   'utterly',
#   'embarrass',
#   'customer',
#   'service',
#   'wo',
#   'even',
#   'answer',
#   'dang',
#   'phone'],
#  ['please',
#   'bring',
#   'back',
#   'direct',
#   'route',
#   'notice',
#   'miss',
#   'start',
#   'late',
#   'flight',
#   'august',
#   'flight',
#   'always',
#   'pack'],
#  ['want', 'get', 'home'],
#  ['phone',
#   'line',
#   'disconnect',
#   'queue',
#   'answer',
#   'phone',
#   'line',
#   'simply',
#   'disconnect',
#   'call'],
#  ['sit',
#   'plane',
#   'many',
#   'predictable',
#   'mechanical',
#   'problem',
#   'still',
#   'get',
#   'bad'],
#  ['upgrade'],
#  ['never',
#   'receive',
#   'horrible',
#   'service',
#   'treat',
#   'poorly',
#   'today',
#   'excuse',
#   'attitude',
#   'amp',
#   'rip',
#   'ticket'],
#  ['get',
#   'copy',
#   'last',
#   'flight',
#   'show',
#   'original',
#   'time',
#   'delay',
#   'need',
#   'work',
#   'thanks'],
#  ['get', 'honest', 'update', 'departure', 'flite', 'plane', 'infant', 'child'],
#  ['wait', 'gate', 'open', 'back', 'go', 'good', 'maybe', 'get'],
#  ['maintenance',
#   'sit',
#   'two',
#   'day',
#   'frozen',
#   'line',
#   'find',
#   'board',
#   'come'],
#  ['seriously',
#   'bad',
#   'remember',
#   'last',
#   'time',
#   'someone',
#   'know',
#   'flight',
#   'delay',
#   'cancel',
#   'etc'],
#  ['united',
#   'wont',
#   'transfer',
#   'flight',
#   'ticket',
#   'accompany',
#   'yr',
#   'old',
#   'active',
#   'military',
#   'mom',
#   'emergency',
#   'brain',
#   'surgery',
#   'wow'],
#  ['ticket',
#   'counter',
#   'people',
#   'help',
#   'want',
#   'charge',
#   'money',
#   'even',
#   'horrible',
#   'day'],
#  ['unite', 'flt', 'would', 'credit', 'mile', 'full', 'fare'],
#  ['need', 'know', 'do', 'like', 'promise', 'would', 'yesterday'],
#  ['kudos', 'do', 'head', 'warmer', 'weather'],
#  ['try',
#   'fly',
#   'live',
#   'send',
#   'home',
#   'bullshit',
#   'as',
#   'customer',
#   'service'],
#  ['stay',
#   'overnight',
#   'meet',
#   'bag',
#   'hope',
#   'stay',
#   'put',
#   'get',
#   'put',
#   'flight'],
#  ['united', 'severely', 'staff'],
#  ['fantastic', 'thanks', 'try', 'tweet', 'photo', 'view'],
#  ['love', 'companion', 'pas', 'qualify', 'year'],
#  ['say', 'aa', 'provide', 'route', 'china', 'base', 'federal', 'law', 'unite'],
#  ['board', 'pass', 'compatible', 'passbook'],
#  ['disaster',
#   'flight',
#   'miss',
#   'passenger',
#   'count',
#   'since',
#   'do',
#   'manually',
#   'really'],
#  ['suck', 'big', 'donkey', 'ball'],
#  ['thanks', 'confirmation', 'number', 'appreciate', 'help'],
#  ['make',
#   'feel',
#   'like',
#   'criminal',
#   'want',
#   'sit',
#   'near',
#   'year',
#   'old',
#   'flight'],
#  ['already', 'make', 'arrangement'],
#  ['add', 'frequent', 'number', 'website', 'help'],
#  ['ticket', 'book', 'arrival', 'time', 'reflect', 'est', 'time'],
#  ['unite',
#   'lot',
#   'unhappy',
#   'cold',
#   'people',
#   'bridge',
#   'freeze',
#   'temp',
#   'hour',
#   'give',
#   'info'],
#  ['love', 'help', 'grandmother', 'dc', 'go', 'bucket', 'list'],
#  ['united',
#   'want',
#   'book',
#   'fare',
#   'mile',
#   'flight',
#   'option',
#   'pay',
#   'flight',
#   'mile',
#   'ump',
#   'visa',
#   'thanks'],
#  ['united', 'email', 'available'],
#  ['united', 'yes', 'wait', 'four', 'hour', 'one', 'able', 'help'],
#  ['thank', 'ca', 'get', 'flight', 'hold', 'cancel', 'flight'],
#  ['flight',
#   'schedule',
#   'tell',
#   'flight',
#   'cancel',
#   'sit',
#   'cold',
#   'plane',
#   'hour'],
#  ['united',
#   'yes',
#   'plenty',
#   'seat',
#   'available',
#   'refuse',
#   'give',
#   'one',
#   'million',
#   'mile'],
#  ['united',
#   'arrive',
#   'agent',
#   'mass',
#   'confusion',
#   'send',
#   'fro',
#   'employee',
#   'rude',
#   'unhelpful'],
#  ['terminal',
#   'still',
#   'bad',
#   'smelly',
#   'airport',
#   'ever',
#   'thanks',
#   'nothing'],
#  ['united',
#   'great',
#   'decision',
#   'make',
#   'skill',
#   'flight',
#   'ops',
#   'bag',
#   'make',
#   'minute',
#   'connection',
#   'flight',
#   'push',
#   'early',
#   'disappointed'],
#  ['check', 'yesterday', 'look', 'like', 'something', 'change'],
#  ['united', 'weigh', 'check', 'bag'],
#  ['check',
#   'online',
#   'state',
#   'status',
#   'close',
#   'mean',
#   'yet',
#   'able',
#   'reach',
#   'live',
#   'person'],
#  ['united',
#   'ask',
#   'dm',
#   'ignore',
#   'please',
#   'assist',
#   'change',
#   'another',
#   'flight',
#   'avoid'],
#  ['approach'],
#  ['unite',
#   'amp',
#   'finally',
#   'tell',
#   'use',
#   'front',
#   'plane',
#   'though',
#   'row',
#   'behind',
#   'use',
#   'issue'],
#  ['early',
#   'flight',
#   'gt',
#   'amp',
#   'gt',
#   'new',
#   'york',
#   'currently',
#   'book',
#   'flight'],
#  ['unite',
#   'last',
#   'night',
#   'wait',
#   'forever',
#   'gate',
#   'someone',
#   'corporate',
#   'dispatch',
#   'forget',
#   'call',
#   'crew'],
#  ['unite', 'seriously', 'flight', 'airline', 'without'],
#  ['unite',
#   'tell',
#   'change',
#   'flight',
#   'airport',
#   'ac',
#   'cant',
#   'find',
#   'reservation',
#   'whats',
#   'wrong'],
#  ['unfortunately',
#   'available',
#   'option',
#   'current',
#   'system',
#   'sorry',
#   'guy',
#   'certain',
#   'fail',
#   'fix'],
#  ['united',
#   'need',
#   'apology',
#   'need',
#   'bag',
#   'take',
#   'minute',
#   'land',
#   'get',
#   'unacceptable'],
#  ['see',
#   'photo',
#   'scale',
#   'model',
#   'amp',
#   'wheel',
#   'deflator',
#   'specify',
#   'chapter'],
#  ['united',
#   'fly',
#   'expect',
#   'ice',
#   'amp',
#   'snow',
#   'start',
#   'look',
#   'travel',
#   'waiver',
#   'thanks'],
#  ['thanks', 'get', 'back', 'find', 'airline', 'future'],
#  ['know', 'need', 'stat'],
#  ['unite',
#   'patient',
#   'luxurious',
#   'middle',
#   'seat',
#   'next',
#   'delayed',
#   'flight'],
#  ['hour', 'tarmac', 'still', 'ca', 'get', 'response', 'week', 'unacceptable'],
#  ['happen',
#   'customer',
#   'service',
#   'cancel',
#   'flight',
#   'day',
#   'amp',
#   'uninformed',
#   'unapologetic',
#   'staff'],
#  ['united', 'zero', 'entertainment', 'system'],
#  ['overweight', 'pull', 'dozen', 'passenger', 'luggage', 'seriously'],
#  ['disappoint',
#   'flight',
#   'back',
#   'pr',
#   'cancel',
#   'next',
#   'day',
#   'delay',
#   'one',
#   'compensation'],
#  ['unite', 'good', 'customer', 'service', 'john', 'airport'],
#  ['wait',
#   'delayed',
#   'plane',
#   'sit',
#   'plane',
#   'hour',
#   'wait',
#   'late',
#   'flight',
#   'passenger'],
#  ['united', 'always', 'help', 'communicate', 'customer'],
#  ['united',
#   'customer',
#   'service',
#   'unbelievably',
#   'bad',
#   'abysmal',
#   'phone',
#   'well',
#   'tonight',
#   'hang',
#   'yr'],
#  ['time', 'fly', 'southwest', 'two', 'year', 'another', 'trip', 'back'],
#  ['priority', 'baggage', 'evidently', 'mean', 'come', 'last'],
#  ['united',
#   'mention',
#   'one',
#   'bag',
#   'infant',
#   'car',
#   'seat',
#   'amp',
#   'stick',
#   'yr',
#   'poor',
#   'replacement',
#   'icy',
#   'road'],
#  ['united', 'thanks', 'check'],
#  ['understand', 'even', 'put', 'hold', 'say', 'try', 'late', 'goodbye'],
#  ['united',
#   'wo',
#   'check',
#   'carry',
#   'watch',
#   'handler',
#   'throw',
#   'bag',
#   'miss',
#   'belt',
#   'sit',
#   'min'],
#  ['rerouted',
#   'bf',
#   'flight',
#   'diabetic',
#   'little',
#   'insulin',
#   'even',
#   'though',
#   'try',
#   'change',
#   'agent',
#   'would'],
#  ['lot', 'talk', 'year', 'old', 'plane', 'old', 'shame'],
#  ['flight', 'need', 'change', 'asap', 'help', 'ca', 'get'],
#  ['unite',
#   'change',
#   'way',
#   'stick',
#   'premiere',
#   'loyal',
#   'customer',
#   'make',
#   'thing',
#   'hard',
#   'loyal'],
#  ['know',
#   'door',
#   'close',
#   'minute',
#   'takeoff',
#   'stop',
#   'tell',
#   'flight',
#   'leave',
#   'minute',
#   'board'],
#  ['unite', 'hope', 'see', 'issue', 'return', 'flight', 'tomorrow'],
#  ['united', 'customer', 'service'],
#  ['wife',
#   'sick',
#   'wait',
#   'line',
#   'see',
#   'agent',
#   'phone',
#   'agent',
#   'say',
#   'nothing',
#   'til'],
#  ['ruin',
#   'vacation',
#   'leave',
#   'right',
#   'would',
#   'think',
#   'airline',
#   'cancel',
#   'flight',
#   'ticket',
#   'without',
#   'tell',
#   'buyer'],
#  ['guy',
#   'get',
#   'something',
#   'inability',
#   'check',
#   'online',
#   'international',
#   'flight'],
#  ['seriously',
#   'flight',
#   'delay',
#   'due',
#   'new',
#   'ground',
#   'staff',
#   'miss',
#   'connection',
#   'man',
#   'argue',
#   'hotel'],
#  ['unite', 'line', 'rebook', 'due', 'weather', 'issue', 'good'],
#  ['redeem',
#   'pas',
#   'admiral',
#   'club',
#   'free',
#   'visit',
#   'card',
#   'membership',
#   'bring',
#   'companion'],
#  ['one', 'one'],
#  ['guy',
#   'continue',
#   'impress',
#   'crew',
#   'gate',
#   'family',
#   'seat',
#   'issue',
#   'professional'],
#  ['charge',
#   'ticket',
#   'change',
#   'fee',
#   'incur',
#   'mysterious',
#   'cost',
#   'incur',
#   'unite'],
#  ['take', 'call', 'need', 'change', 'flight'],
#  ['flight',
#   'sit',
#   'fully',
#   'load',
#   'hour',
#   'air',
#   'condition',
#   'barely',
#   'work'],
#  ['drop',
#   'passenger',
#   'small',
#   'baby',
#   'infant',
#   'terminal',
#   'unloading',
#   'baby',
#   'officer',
#   'writes',
#   'ticket'],
#  ['continue', 'amaze', 'amazing', 'customer', 'service', 'thank'],
#  ['hilarious', 'flight', 'attendant', 'tonight'],
#  ['people',
#   'cruel',
#   'stupid',
#   'post',
#   'personal',
#   'email',
#   'damn',
#   'internet',
#   'lose',
#   'mind'],
#  ['narrowly', 'make', 'standby', 'lot', 'snag', 'trip'],
#  ['thank', 'thankful'],
#  ['take',
#   'flight',
#   'yesterday',
#   'bag',
#   'go',
#   'today',
#   'bag',
#   'go',
#   'back',
#   'still',
#   'bag'],
#  ['one', 'agent', 'help', 'stagnant', 'line', 'almost', 'customer', 'super'],
#  ['pair', 'ticket', 'show', 'love', 'go'],
#  ['get',
#   'dupe',
#   'connection',
#   'flight',
#   'sneaky',
#   'wo',
#   'give',
#   'seat',
#   'early',
#   'flight',
#   'availability',
#   'shameful'],
#  ['really', 'hear', 'mouth', 'bag', 'situation'],
#  ['phone', 'number', 'ca', 'find', 'call', 'flight', 'reservation'],
#  ['thanks',
#   'would',
#   'well',
#   'gate',
#   'agent',
#   'charlotte',
#   'boarding',
#   'flight'],
#  ['always', 'pleasure'],
#  ['disappoints',
#   'cancel',
#   'flighted',
#   'flight',
#   'miss',
#   'appointment',
#   'promise',
#   'refund',
#   'lie'],
#  ['unite',
#   'ca',
#   'get',
#   'anyone',
#   'deal',
#   'person',
#   'cowardly',
#   'customer',
#   'service',
#   'ca',
#   'look',
#   'eye',
#   'anyone'],
#  ['something',
#   'wrong',
#   'website',
#   'matter',
#   'flight',
#   'select',
#   'say',
#   'longer',
#   'available'],
#  ['multiple',
#   'attempt',
#   'finally',
#   'able',
#   'submit',
#   'late',
#   'flight',
#   'last',
#   'night'],
#  ['break',
#   'stroller',
#   'wife',
#   'baby',
#   'gate',
#   'check',
#   'tell',
#   'problem',
#   'call',
#   'list',
#   'preferred',
#   'line'],
#  ['unfortunately', 'hop', 'catch', 'one', 'sometime', 'near', 'future'],
#  ['mean',
#   'take',
#   'time',
#   'write',
#   'physical',
#   'letter',
#   'fraud',
#   'department',
#   'email',
#   'telephone',
#   'right'],
#  ['trip', 'cut', 'hr', 'short', 'due', 'flight', 'peanut', 'ask', 'receive'],
#  ['united', 'please', 'follow', 'dm', 'miss', 'bag'],
#  ['please', 'secure', 'shelf', 'business', 'class', 'airplane'],
#  ['receive', 'actually', 'thank'],
#  ['cover', 'cost', 'car', 'service', 'wait', 'time'],
#  ['cancel',
#   'flight',
#   'first',
#   'priority',
#   'ticket',
#   'bump',
#   'lose',
#   'customer',
#   'people',
#   'furious'],
#  ['connect',
#   'person',
#   'without',
#   'wait',
#   'hour',
#   'hold',
#   'still',
#   'able',
#   'resolve',
#   'problem'],
#  ['reservation', 'number', 'none', 'phone', 'work', 'make', 'difficult'],
#  ['check',
#   'right',
#   'mark',
#   'board',
#   'group',
#   'kid',
#   'age',
#   'amp',
#   'want',
#   'split',
#   'sld'],
#  ['flight', 'booze', 'serve', 'min', 'give'],
#  ['weather',
#   'bad',
#   'would',
#   'folk',
#   'try',
#   'extra',
#   'hard',
#   'communicate',
#   'load',
#   'bag',
#   'onto',
#   'flight',
#   'anything'],
#  ['flight',
#   'use',
#   'gate',
#   'plane',
#   'awful',
#   'board',
#   'process',
#   'hour',
#   'half',
#   'late',
#   'flight'],
#  ['unite',
#   'staff',
#   'rather',
#   'efficient',
#   'get',
#   'solution',
#   'freak',
#   'little',
#   'limbo',
#   'air'],
#  ['united',
#   'flight',
#   'cancel',
#   'flight',
#   'morning',
#   'due',
#   'operation',
#   'mean',
#   'thank',
#   'god',
#   'wake',
#   'early',
#   'today'],
#  ['take',
#   'hour',
#   'offload',
#   'bag',
#   'especially',
#   'take',
#   'min',
#   'get',
#   'get',
#   'plane',
#   'land'],
#  ['like',
#   'apologize',
#   'gate',
#   'agent',
#   'flight',
#   'aware',
#   'zone',
#   'nine',
#   'precious',
#   'gem'],
#  ['late', 'get', 'call', 'back', 'immediately', 'disconnect'],
#  ['wo',
#   'waive',
#   'fee',
#   'due',
#   'ca',
#   'use',
#   'credit',
#   'pay',
#   'fee',
#   'get',
#   'destination',
#   'use',
#   'tic'],
#  ['insult',
#   'offer',
#   'non',
#   'require',
#   'voucher',
#   'goodwill',
#   'offer',
#   'least',
#   'bag',
#   'fly',
#   'round',
#   'trip'],
#  ['ca',
#   'even',
#   'use',
#   'return',
#   'flight',
#   'home',
#   'change',
#   'fee',
#   'charge',
#   'expensive',
#   'force',
#   'purchase',
#   'new',
#   'ticket'],
#  ['unite', 'line', 'people', 'deep'],
#  ['rep',
#   'unable',
#   'change',
#   'reservation',
#   'system',
#   'check',
#   'unaware',
#   'cancelled',
#   'flight',
#   'get',
#   'word',
#   'night'],
#  ['united',
#   'give',
#   'service',
#   'terrible',
#   'force',
#   'use',
#   'united',
#   'certain',
#   'route',
#   'never',
#   'would'],
#  ['get',
#   'kind',
#   'update',
#   'delayed',
#   'flight',
#   'really',
#   'need',
#   'back',
#   'home',
#   'tonight'],
#  ['impression',
#   'hour',
#   'delay',
#   'flight',
#   'equipment',
#   'failure',
#   'compensation',
#   'offer'],
#  ['look', 'like', 'open', 'schedule', 'sale', 'know', 'time'],
#  ['would',
#   'appreciate',
#   'please',
#   'send',
#   'page',
#   'long',
#   'form',
#   'amp',
#   'limited',
#   'character',
#   'direct',
#   'email'],
#  ['email'],
#  ['united',
#   'divert',
#   'miss',
#   'connect',
#   'flight',
#   'tell',
#   'bag',
#   'way',
#   'people',
#   'care'],
#  ['unite', 'need', 'assistance', 'line', 'door', 'kid'],
#  ['united',
#   'put',
#   'together',
#   'serious',
#   'email',
#   'issue',
#   'arise',
#   'vacation',
#   'due',
#   'staff',
#   'post'],
#  ['upon', 'enter', 'plane', 'stewardess', 'water', 'please', 'take', 'seat'],
#  ['amount',
#   'money',
#   'spend',
#   'hotel',
#   'week',
#   'flight',
#   'cancel',
#   'another',
#   'flight',
#   'make',
#   'money',
#   'lose'],
#  ['flight',
#   'else',
#   'get',
#   'spot',
#   'rude',
#   'employee',
#   'coach',
#   'give',
#   'id',
#   'say',
#   'cute',
#   'red',
#   'head'],
#  ['thanks',
#   'bummer',
#   'poor',
#   'planning',
#   'part',
#   'assume',
#   'card',
#   'passbook',
#   'wo',
#   'work',
#   'either'],
#  ['still', 'cricket', 'customer', 'service'],
#  ['unite', 'always', 'hop', 'improvement'],
#  ['merger', 'cluster', 'inefficiency', 'misinformation', 'go', 'do'],
#  ['much', 'respect'],
#  ['really', 'easy', 'local', 'get', 'strip', 'book'],
#  ['charlotte',
#   'staff',
#   'need',
#   'prayer',
#   'disappoint',
#   'response',
#   'mishap',
#   'piss',
#   'people'],
#  ['unscheduled',
#   'aircraft',
#   'change',
#   'please',
#   'good',
#   'system',
#   'place',
#   'worth',
#   'paid',
#   'upgrade',
#   'refund'],
#  ['unite',
#   'air',
#   'another',
#   'miss',
#   'go',
#   'strike',
#   'family',
#   'amp',
#   'miss',
#   'please',
#   'see'],
#  ['thanks', 'bad', 'make', 'two', 'day', 'train', 'trip', 'look', 'appeal'],
#  ['united', 'get', 'ridiculous', 'miss', 'connection'],
#  ['united',
#   'really',
#   'clean',
#   'food',
#   'coffee',
#   'stain',
#   'area',
#   'around',
#   'seat',
#   'new',
#   'passenger',
#   'come',
#   'aboard',
#   'gross'],
#  ['united',
#   'miss',
#   'flight',
#   'attendant',
#   'delay',
#   'flight',
#   'prime',
#   'example',
#   'person',
#   'impact',
#   'people',
#   'gt'],
#  ['call',
#   'number',
#   'list',
#   'sure',
#   'next',
#   'get',
#   'real',
#   'live',
#   'person',
#   'line'],
#  ['change', 'fee', 'price', 'new', 'ticket', 'logical'],
#  ['stop', 'madness', 'rt', 'fleet'],
#  ['united',
#   'send',
#   'info',
#   'via',
#   'dm',
#   'appreciate',
#   'help',
#   'consideration'],
#  ['service', 'rep', 'say', 'dumb', 'tone', 'voice', 'like', 'know'],
#  ['try',
#   'get',
#   'dad',
#   'wheelchair',
#   'one',
#   'answer',
#   'try',
#   'call',
#   'back',
#   'time'],
#  ['hold',
#   'approach',
#   'hr',
#   'issue',
#   'change',
#   'ticket',
#   'online',
#   'frustrating'],
#  ['united', 'thank'],
#  ['united',
#   'thanks',
#   'effort',
#   'get',
#   'early',
#   'though',
#   'make',
#   'complaint',
#   'refund',
#   'lose',
#   'one',
#   'business',
#   'day',
#   'tomorrow'],
#  ['lack',
#   'communication',
#   'office',
#   'customer',
#   'amp',
#   'never',
#   'update',
#   'system',
#   'guy',
#   'establish',
#   'mess'],
#  ['much',
#   'pay',
#   'fee',
#   'plus',
#   'hotel',
#   'food',
#   'change',
#   'could',
#   'fly',
#   'reliable',
#   'airline'],
#  ['seriously', 'want', 'work', 'social', 'team', 'rt'],
#  ['right',
#   'delay',
#   'crabby',
#   'also',
#   'allow',
#   'one',
#   'family',
#   'member',
#   'purchase',
#   'check',
#   'hold',
#   'row'],
#  ['united', 'guy', 'suck'],
#  ['united', 'thank', 'person', 'could', 'get', 'flight', 'rout', 'go'],
#  ['unite',
#   'lose',
#   'bag',
#   'leave',
#   'cruise',
#   'today',
#   'buy',
#   'new',
#   'stuff',
#   'customer',
#   'service',
#   'non',
#   'existent'],
#  ['customer',
#   'service',
#   'rep',
#   'patient',
#   'help',
#   'booking',
#   'problem',
#   'cancel',
#   'flighted',
#   'flight',
#   'get'],
#  ['faster', 'way', 'get', 'sc', 'make', 'stay', 'night', 'delayed', 'flight'],
#  ['highly',
#   'disappoint',
#   'baggage',
#   'service',
#   'merge',
#   'guy',
#   'lose',
#   'bag',
#   'miss',
#   'item'],
#  ['program',
#   'complete',
#   'joke',
#   'company',
#   'value',
#   'loyal',
#   'look',
#   'another',
#   'airliner'],
#  ['understand',
#   'need',
#   'drain',
#   'lavatory',
#   'fear',
#   'freeze',
#   'policy',
#   'check',
#   'board',
#   'come'],
#  ['united',
#   'hope',
#   'nicer',
#   'flight',
#   'time',
#   'try',
#   'thing',
#   'right',
#   'sell',
#   'ticket'],
#  ['thank',
#   'thank',
#   'thank',
#   'last',
#   'attempt',
#   'win',
#   'ticket',
#   'success',
#   'could',
#   'happy'],
#  ['hate'],
#  ['get', 'together', 'perfect', 'combination', 'delay', 'cancel'],
#  ['unite',
#   'may',
#   'dislike',
#   'delay',
#   'pay',
#   'agreement',
#   'pay',
#   'get',
#   'destination',
#   'certain',
#   'time'],
#  ['try', 'get', 'relation', 'another', 'use'],
#  ['yesterday',
#   'flight',
#   'want',
#   'sale',
#   'within',
#   'point',
#   'range',
#   'today',
#   'way',
#   'guy',
#   'still',
#   'honor'],
#  ['unite',
#   'possible',
#   'add',
#   'known',
#   'traveler',
#   'number',
#   'ticket',
#   'flight',
#   'book',
#   'problem'],
#  ['try', 'get', 'hour', 'someone', 'call', 'please'],
#  ['fleet'],
#  ['thanks', 'opportunity'],
#  ['disappoint',
#   'missed',
#   'connection',
#   'roc',
#   'reimbursement',
#   'even',
#   'tho',
#   'friend',
#   'pilot',
#   'say',
#   'due'],
#  ['lipstick',
#   'pig',
#   'still',
#   'pig',
#   'new',
#   'baggage',
#   'claim',
#   'disaster',
#   'chair',
#   'wait',
#   'baggage',
#   'fail'],
#  ['prime', 'ticket', 'seat', 'get', 'switch', 'aa', 'sure', 'go'],
#  ['fleet', 'good'],
#  ['great', 'thank'],
#  ['usual',
#   'next',
#   'flight',
#   'show',
#   'time',
#   'suppose',
#   'leave',
#   'minute',
#   'board'],
#  ['opal', 'dragon', 'book', 'dragon', 'weave', 'murder', 'way'],
#  ['happen', 'locate'],
#  ['phone', 'call', 'email', 'cancel', 'flight', 'flight', 'would', 'lovely'],
#  ['please',
#   'thank',
#   'tammy',
#   'baggage',
#   'claim',
#   'excellent',
#   'customer',
#   'service',
#   'complaint'],
#  ['united',
#   'mean',
#   'within',
#   'one',
#   'week',
#   'file',
#   'compensation',
#   'complaint',
#   'website'],
#  ['unite',
#   'thanks',
#   'help',
#   'get',
#   'need',
#   'issue',
#   'guess',
#   'sit',
#   'awhile',
#   'longer'],
#  ['airline',
#   'rather',
#   'poor',
#   'right',
#   'wait',
#   'take',
#   'suppose',
#   'take',
#   'hour',
#   'minute',
#   'ago'],
#  ['three', 'hour', 'hold', 'disconnect', 'conf', 'need', 'home', 'interview'],
#  ['flight', 'gate', 'agent', 'plane', 'nice', 'customer', 'service'],
#  ['united',
#   'unfortunately',
#   'bad',
#   'experience',
#   'fly',
#   'crew',
#   'bad',
#   'delay'],
#  ['state',
#   'issue',
#   'plane',
#   'move',
#   'cargo',
#   'door',
#   'open',
#   'plane',
#   'little',
#   'strange'],
#  ['united',
#   'thanks',
#   'try',
#   'take',
#   'money',
#   'without',
#   'notice',
#   'industry',
#   'cancel',
#   'flight',
#   'service',
#   'refund',
#   'issue'],
#  ['unite',
#   'ca',
#   'leave',
#   'tarmac',
#   'unite',
#   'gate',
#   'agent',
#   'agree',
#   'head',
#   'count',
#   'min',
#   'count',
#   'people',
#   'max'],
#  ['flight',
#   'delay',
#   'hour',
#   'reason',
#   'give',
#   'sure',
#   'love',
#   'fly',
#   'airline'],
#  ['united',
#   'vacation',
#   'go',
#   'ruin',
#   'day',
#   'rain',
#   'change',
#   'fee',
#   'nearly',
#   'cost',
#   'original',
#   'flight',
#   'help'],
#  ['way',
#   'help',
#   'entry',
#   'event',
#   'boyfriend',
#   'amp',
#   'fan',
#   'since',
#   'awesome'],
#  ['think',
#   'guy',
#   'do',
#   'mess',
#   'make',
#   'bad',
#   'airline',
#   'ruin',
#   'hope',
#   'dream'],
#  ['board', 'flight', 'still', 'sit', 'runway', 'lot', 'fun'],
#  ['wait',
#   'hold',
#   'long',
#   'wait',
#   'hold',
#   'forever',
#   'never',
#   'receive',
#   'confirm',
#   'place',
#   'help'],
#  ['unite',
#   'interview',
#   'yesterday',
#   'flight',
#   'attendant',
#   'last',
#   'person',
#   'recruiter',
#   'say',
#   'lose',
#   'file',
#   'come',
#   'back',
#   'interview'],
#  ['united',
#   'item',
#   'mine',
#   'mysteriously',
#   'end',
#   'checked',
#   'bag',
#   'yow',
#   'flight',
#   'miss',
#   'black',
#   'box'],
#  ['united', 'thank', 'try', 'two', 'day', 'set'],
#  ['shit', 'fix', 'jump', 'close', 'bloody', 'fuck', 'emergency', 'exit'],
#  ['jump', 'market'],
#  ['conference', 'number', 'speak', 'finally', 'fix', 'mine', 'hour'],
#  ['anyone',
#   'make',
#   'good',
#   'effort',
#   'retain',
#   'customer',
#   'easy',
#   'fix',
#   'want',
#   'travel',
#   'aa'],
#  ['unite',
#   'premier',
#   'desk',
#   'able',
#   'rebook',
#   'friend',
#   'problem',
#   'pay',
#   'checked',
#   'bag'],
#  ['fleet'],
#  ['guy', 'hold', 'flight', 'thank', 'take', 'thanks'],
#  ['united',
#   'flight',
#   'gate',
#   'agent',
#   'try',
#   'prevent',
#   'take',
#   'bag',
#   'use',
#   'year',
#   'flight',
#   'crew',
#   'reasonable'],
#  ['thank'],
#  ['success',
#   'make',
#   'flight',
#   'please',
#   'thank',
#   'crew',
#   'great',
#   'time',
#   'recovery'],
#  ['consider',
#   'add',
#   'call',
#   'back',
#   'someone',
#   'free',
#   'feature',
#   'support',
#   'line'],
#  ['day', 'ago', 'miss', 'warm', 'weather'],
#  ['united',
#   'unsmiling',
#   'tell',
#   'hotel',
#   'shuttle',
#   'come',
#   'like',
#   'every',
#   'minute',
#   'breezy',
#   'min',
#   'late',
#   'take',
#   'cab',
#   'go',
#   'reimburse'],
#  ['send', 'trusted', 'traveler', 'id', 'add', 'reservation'],
#  ['thank', 'know', 'busy', 'today', 'help', 'would', 'appreciate'],
#  ['still', 'wait', 'bag', 'flight', 'land', 'hour', 'ago'],
#  ['delayed',
#   'flight',
#   'one',
#   'amp',
#   'gate',
#   'agent',
#   'still',
#   'mumble',
#   'word',
#   'folk',
#   'get',
#   'anxious'],
#  ['dude',
#   'name',
#   'desk',
#   'charlotte',
#   'incredibly',
#   'professional',
#   'helpful',
#   'crazy',
#   'angry',
#   'people',
#   'tonight'],
#  ['kudos', 'add', 'passbook', 'app', 'love'],
#  ['unite',
#   'bad',
#   'oh',
#   'ca',
#   'delay',
#   'reason',
#   'way',
#   'flight',
#   'cancel',
#   'flight',
#   'reason',
#   'less',
#   'day',
#   'return'],
#  ['find', 'funny', 'responds', 'customer', 'service', 'bad'],
#  ['stick', 'hr', 'delay', 'say', 'snow', 'snow', 'weather', 'map'],
#  ['thank', 'guy', 'awesome'],
#  ['fat', 'man', 'stick', 'airplane', 'bathroom'],
#  ['sorry', 'mean', 'flight', 'suppose', 'depart', 'say', 'issue'],
#  ['unite',
#   'receive',
#   'one',
#   'previously',
#   'check',
#   'odd',
#   'say',
#   'complaint',
#   'associate'],
#  ['definitely', 'new', 'favorite', 'airline'],
#  ['united',
#   'arrive',
#   'hour',
#   'late',
#   'last',
#   'year',
#   'hr',
#   'inflight',
#   'entertainment'],
#  ['although', 'totally', 'answer', 'look', 'appreciate', 'prompt', 'response'],
#  ['easily', 'get', 'show', 'need', 'ticket', 'help'],
#  ['whatever', 'mint', 'heart', 'desire'],
#  ['message', 'pic', 'send'],
#  ['thanks'],
#  ['united',
#   'airport',
#   'snow',
#   'removal',
#   'method',
#   'keep',
#   'good',
#   'work',
#   'folk',
#   'become'],
#  ['ability', 'switch', 'flight', 'tell', 'bag'],
#  ['make', 'work', 'luggage', 'know', 'travel', 'happens', 'anyway', 'get'],
#  ['never',
#   'fly',
#   'airway',
#   'share',
#   'nightmare',
#   'story',
#   'many',
#   'others',
#   'know',
#   'fly'],
#  ['united',
#   'delay',
#   'hr',
#   'flight',
#   'finally',
#   'board',
#   'plane',
#   'sit',
#   'half',
#   'hour',
#   'amp',
#   'crew',
#   'hr',
#   'limit',
#   'amp',
#   'deplane',
#   'unacceptable'],
#  ['hold', 'minute', 'fly', 'answer', 'phone'],
#  ['aa',
#   'cancel',
#   'flight',
#   'without',
#   'courtesy',
#   'notify',
#   'alternative',
#   'poor'],
#  ['time', 'occur', 'week', 'patient', 'choice', 'antitrust', 'issue'],
#  ['hold', 'rebook', 'flight', 'hr', 'rebook', 'website', 'crash'],
#  ['yes'],
#  ['delay', 'system'],
#  ['try',
#   'check',
#   'ct',
#   'flight',
#   'desktop',
#   'website',
#   'work',
#   'sort',
#   'cache',
#   'bug'],
#  ['beautiful', 'design', 'right', 'cool', 'still', 'book', 'ticket', 'secure'],
#  ['unite', 'hear', 'sure'],
#  ['book', 'flight', 'easy'],
#  ['line', 'wait', 'minute'],
#  ['flt', 'could', 'extend', 'wait', 'gate', 'close', 'face', 'fire'],
#  ['last', 'name'],
#  ['thanks',
#   'actually',
#   'make',
#   'connection',
#   'flight',
#   'delay',
#   'guess',
#   'delay',
#   'bad',
#   'thing'],
#  ['know', 'may', 'also', 'work', 'home', 'thanks', 'nothing'],
#  ['know',
#   'leave',
#   'something',
#   'last',
#   'flight',
#   'literally',
#   'run',
#   'make',
#   'connection',
#   'retrieve',
#   'please'],
#  ['offer', 'flight', 'pay', 'change', 'time', 'do', 'ruin', 'cruise', 'plan'],
#  ['unite',
#   'say',
#   'customer',
#   'care',
#   'report',
#   'anyone',
#   'response',
#   'humiliate',
#   'company',
#   'serve',
#   'public'],
#  ['united', 'sit', 'middle', 'first', 'time', 'hope', 'work', 'well'],
#  ['airways', 'corporation', 'update', 'say', 'market', 'bureau'],
#  ['least', 'get', 'response', 'via', 'twitter', 'go', 'yesterday'],
#  ['please',
#   'help',
#   'aa',
#   'cancel',
#   'advise',
#   'book',
#   'problem',
#   'refund',
#   'child',
#   'need',
#   'make',
#   'plan'],
#  ['seat', 'next', 'flight', 'tray', 'table', 'fall'],
#  ['united',
#   'flight',
#   'gate',
#   'tell',
#   'ray',
#   'somehow',
#   'make',
#   'flight',
#   'wait',
#   'one'],
#  ['airline'],
#  ['end',
#   'miss',
#   'connection',
#   'please',
#   'see',
#   'agent',
#   'nope',
#   'take',
#   'yet',
#   'still'],
#  ['hold', 'hour', 'wait', 'speak', 'someone', 'cancelled', 'flight'],
#  ['profit',
#   'maximization',
#   'top',
#   'priority',
#   'nothing',
#   'else',
#   'even',
#   'register',
#   'dinosaurs'],
#  ['fly', 'week', 'bring', 'blanket', 'freeze'],
#  ['united',
#   'great',
#   'flight',
#   'small',
#   'plane',
#   'ever',
#   'smooth',
#   'land',
#   'ever'],
#  ['thanks',
#   'submit',
#   'damage',
#   'bag',
#   'complaint',
#   'online',
#   'anything',
#   'else'],
#  ['eagle', 'always', 'late', 'flight'],
#  ['look', 'status', 'flight', 'schedule', 'tomorrow', 'morning', 'thank'],
#  ['hypocrisy',
#   'rt',
#   'unite',
#   'sorry',
#   'able',
#   'offer',
#   'full',
#   'refund',
#   'exchange',
#   'rate',
#   'hop'],
#  ['united',
#   'terrible',
#   'illogical',
#   'cancel',
#   'connection',
#   'make',
#   'pay',
#   'check',
#   'bag',
#   'lose',
#   'bag'],
#  ['unite',
#   'speak',
#   'united',
#   'customer',
#   'service',
#   'rep',
#   'night',
#   'flight',
#   'confirm',
#   'everything',
#   'reservation'],
#  ['good', 'news', 'get', 'fix'],
#  ['word', 'whether', 'flight', 'charlotte', 'connection', 'hold'],
#  ['important', 'accept', 'others'],
#  ['change',
#   'travel',
#   'plan',
#   'amp',
#   'call',
#   'get',
#   'help',
#   'sea',
#   'busy',
#   'amp',
#   'hang',
#   'give'],
#  ['flight', 'cancel', 'today', 'deserve'],
#  ['airway', 'joke', 'never', 'deal', 'bad', 'service'],
#  ['read', 'fleet'],
#  ['really', 'unhelpful', 'ca', 'rebook', 'online'],
#  ['flight', 'full'],
#  ['rock',
#   'hit',
#   'plane',
#   'delay',
#   'never',
#   'easy',
#   'day',
#   'airways',
#   'ya',
#   'never',
#   'fail',
#   'let'],
#  ['thank', 'excited', 'fly', 'first', 'time'],
#  ['united',
#   'gate',
#   'definitely',
#   'full',
#   'park',
#   'wheel',
#   'chock',
#   'customer',
#   'service',
#   'call',
#   'unmet',
#   'arrival'],
#  ['provide',
#   'direct',
#   'assistance',
#   'colleague',
#   'ticket',
#   'book',
#   'via',
#   'corporate',
#   'account',
#   'help'],
#  ['guess',
#   'need',
#   'book',
#   'flight',
#   'somewhere',
#   'warm',
#   'asap',
#   'suggestion'],
#  ['united',
#   'never',
#   'fly',
#   'guy',
#   'ever',
#   'customer',
#   'service',
#   'piss',
#   'poor',
#   'best'],
#  ['yes',
#   'thanks',
#   'much',
#   'unite',
#   'see',
#   'speak',
#   'reservation',
#   'team',
#   'reinstate',
#   'flight',
#   'thanks'],
#  ['anyone', 'answer', 'phone', 'today', 'listen', 'damn', 'message', 'minute'],
#  ['thank'],
#  ['beyond',
#   'redemption',
#   'baggage',
#   'claim',
#   'look',
#   'like',
#   'luggage',
#   'warehouse'],
#  ['united',
#   'know',
#   'two',
#   'hour',
#   'sit',
#   'plane',
#   'bag',
#   'load',
#   'plane',
#   'weight'],
#  ['deplane', 'fucking', 'time', 'fuck', 'aa'],
#  ['united', 'great', 'job', 'flight', 'lax', 'thanks', 'great', 'flight'],
#  ['willing', 'hold', 'agent', 'helpful', 'keep', 'hang'],
#  ['united', 'delayed', 'another', 'hour'],
#  ['admiral',
#   'club',
#   'rude',
#   'ignorant',
#   'front',
#   'desk',
#   'staff',
#   'fall',
#   'far',
#   'thanks'],
#  ['book', 'work', 'add', 'upgrade', 'seat', 'need', 'upgrade', 'receipt'],
#  ['hi', 'customer', 'service', 'call', 'back', 'sit', 'pick', 'frustrate'],
#  ['flight',
#   'delay',
#   'amp',
#   'ca',
#   'talk',
#   'reach',
#   'anyone',
#   'customer',
#   'service',
#   'high',
#   'call',
#   'volume'],
#  ['united',
#   'miss',
#   'first',
#   'leg',
#   'flight',
#   'pay',
#   'hundred',
#   'keep',
#   'second',
#   'leg',
#   'much',
#   'keep',
#   'earned',
#   'mile'],
#  ['unite',
#   'standby',
#   'delay',
#   'confirm',
#   'aspen',
#   'whose',
#   'flight',
#   'cancel',
#   'flight',
#   'day',
#   'confidence'],
#  ['actually', 'flight'],
#  ['united',
#   'option',
#   'cos',
#   'tonight',
#   'look',
#   'like',
#   'make',
#   'time',
#   'reserve',
#   'hotel',
#   'room'],
#  ['thanks', 'much', 'make', 'cancelled', 'send', 'info'],
#  ['unite',
#   'aware',
#   'flight',
#   'detail',
#   'thanks',
#   'three',
#   'hour',
#   'late',
#   'flight',
#   'crew',
#   'could',
#   'give',
#   'less',
#   'shit'],
#  ['united', 'admit', 'clue', 'flight', 'leave'],
#  ['thank', 'credit', 'nice', 'save'],
#  ['lose',
#   'customer',
#   'today',
#   'flight',
#   'today',
#   'cancel',
#   'find',
#   'call',
#   'customer',
#   'service',
#   'yesterday'],
#  ['still', 'wait', 'flight', 'get', 'money', 'back'],
#  ['unite',
#   'already',
#   'email',
#   'know',
#   'expedient',
#   'contact',
#   'please',
#   'advise',
#   'thanks'],
#  ['flight',
#   'cancel',
#   'try',
#   'get',
#   'refund',
#   'hold',
#   'get',
#   'flight',
#   'would',
#   'depart'],
#  ['thank', 'help', 'resolve', 'problem', 'rock', 'even', 'though'],
#  ['unite',
#   'still',
#   'receive',
#   'response',
#   'please',
#   'direct',
#   'message',
#   'contact',
#   'information'],
#  ['future',
#   'good',
#   'harsh',
#   'weather',
#   'preparedness',
#   'plan',
#   'much',
#   'staff',
#   'call',
#   'everything',
#   'snowball'],
#  ['united',
#   'airline',
#   'cause',
#   'missed',
#   'connection',
#   'would',
#   'think',
#   'would',
#   'take',
#   'whatever',
#   'step',
#   'remedy',
#   'screw'],
#  ['united',
#   'poor',
#   'old',
#   'unite',
#   'never',
#   'seem',
#   'get',
#   'response',
#   'right'],
#  ['bad', 'hour', 'half', 'thanks'],
#  ['thanks'],
#  ['know', 'deal', 'weather', 'hot', 'mess', 'send', 'reinforcement'],
# ...
#   'wait',
#   'connector',
#   'late',
#   'flight',
#   'stick'],
#  ['sure', 'go', 'south', 'breakfast', 'though', 'delay', 'three', 'hour'],
#  ['respond', 'dm'],
#  ['extra',
#   'hour',
#   'travel',
#   'time',
#   'miss',
#   'vacation',
#   'time',
#   'guy',
#   'mess',
#   'professional',
#   'life'],
#  ['united', 'one', 'bag', 'claim', 'want'],
#  ['tell',
#   'drive',
#   'back',
#   'drop',
#   'could',
#   'attempt',
#   'fix',
#   'really',
#   'time',
#   'terrible'],
#  ['united',
#   'thanks',
#   'move',
#   'dad',
#   'mom',
#   'flight',
#   'help',
#   'make',
#   'birthday',
#   'start',
#   'awesomeness',
#   'paw'],
#  ['flight',
#   'delay',
#   'hour',
#   'la',
#   'due',
#   'mechanical',
#   'problem',
#   'handle',
#   'like',
#   'pro',
#   'could',
#   'toss',
#   'free',
#   'drink'],
#  ['thanks'],
#  ['customer',
#   'service',
#   'say',
#   'since',
#   'wife',
#   'setup',
#   'family',
#   'account',
#   'ca',
#   'join',
#   'mine',
#   'year',
#   'help',
#   'fix',
#   'please'],
#  ['give',
#   'hard',
#   'time',
#   'look',
#   'basic',
#   'customer',
#   'service',
#   'aa',
#   'lose',
#   'bag',
#   'eta',
#   'return',
#   'please'],
#  ['find', 'another', 'plane', 'listen', 'vent'],
#  ['friend', 'flight', 'cancel', 'lax', 'anyway', 'help', 'number', 'help'],
#  ['jackpot', 'legroom'],
#  ['point', 'baggage', 'claim', 'ticket', 'scan', 'track'],
#  ['united',
#   'cancel',
#   'flight',
#   'flight',
#   'send',
#   'email',
#   'say',
#   'think',
#   'next',
#   'flight',
#   'customer',
#   'outrage'],
#  ['unite',
#   'try',
#   'go',
#   'far',
#   'away',
#   'possible',
#   'charity',
#   'today',
#   'would',
#   'help',
#   'jailbreak',
#   'rag'],
#  ['unite',
#   'live',
#   'abroad',
#   'flight',
#   'booking',
#   'problem',
#   'flight',
#   'come',
#   'visit',
#   'state'],
#  ['united', 'way'],
#  ['ask', 'load', 'bag', 'flight'],
#  ['stick',
#   'airport',
#   'try',
#   'beat',
#   'storm',
#   'guy',
#   'offer',
#   'nothing',
#   'horrid'],
#  ['take'],
#  ['please', 'please', 'please', 'answer', 'phone'],
#  ['ever',
#   'wonder',
#   'find',
#   'respond',
#   'many',
#   'customer',
#   'complaint',
#   'twitter',
#   'airline',
#   'suck'],
#  ['day', 'bag', 'amaze', 'way', 'neglect', 'customer'],
#  ['deal', 'flight', 'computer', 'network'],
#  ['thing',
#   'change',
#   'ticket',
#   'cancelled',
#   'current',
#   'ticket',
#   'amp',
#   'buy',
#   'replacement',
#   'online'],
#  ['flt',
#   'stop',
#   'heart',
#   'condition',
#   'crew',
#   'awesome',
#   'pilot',
#   'maverick',
#   'divert'],
#  ['complete', 'waste', 'entire', 'day', 'pathetic'],
#  ['unite',
#   'dm',
#   'detail',
#   'back',
#   'start',
#   'phone',
#   'number',
#   'reach',
#   'reply',
#   'either',
#   'online',
#   'phone'],
#  ['unite',
#   'go',
#   'segment',
#   'new',
#   'york',
#   'rt',
#   'delay',
#   'hr',
#   'suck',
#   'bad',
#   'maybe',
#   'another',
#   'line',
#   'bus'],
#  ['frequent', 'airway', 'still', 'get', 'notification', 'thank'],
#  ['finally',
#   'make',
#   'hour',
#   'late',
#   'flight',
#   'get',
#   'food',
#   'voucher',
#   'never',
#   'good',
#   'bye'],
#  ['welcome',
#   'anyone',
#   'work',
#   'condition',
#   'deserve',
#   'thank',
#   'even',
#   'though',
#   'side',
#   'xx'],
#  ['website', 'ugh'],
#  ['unite',
#   'cell',
#   'phone',
#   'record',
#   'need',
#   'check',
#   'see',
#   'converse',
#   'trust',
#   'handle',
#   'good'],
#  ['united',
#   'strand',
#   'fly',
#   'new',
#   'tonight',
#   'stick',
#   'two',
#   'day',
#   'rather',
#   'fly',
#   'wait'],
#  ['united',
#   'force',
#   'check',
#   'baby',
#   'bag',
#   'overbooked',
#   'flight',
#   'complains',
#   'wife',
#   'need',
#   'much',
#   'baby',
#   'unite',
#   'baby',
#   'meal'],
#  ['tho'],
#  ['get',
#   'gate',
#   'time',
#   'watch',
#   'plane',
#   'push',
#   'back',
#   'minute',
#   'need',
#   'glad',
#   'relative',
#   'nearby'],
#  ['hour',
#   'patient',
#   'call',
#   'back',
#   'feature',
#   'pay',
#   'someone',
#   'answer',
#   'phone',
#   'tweet'],
#  ['nice',
#   'aa',
#   'employee',
#   'make',
#   'skillful',
#   'excuse',
#   'late',
#   'due',
#   'cater',
#   'snafu'],
#  ['safety', 'first'],
#  ['thanks', 'airline', 'ruin', 'bag', 'refuse', 'anything'],
#  ['ca', 'unload', 'flight', 'break', 'step', 'wait', 'nearly', 'hour'],
#  ['six',
#   'hour',
#   'even',
#   'gate',
#   'agent',
#   'get',
#   'feed',
#   'leave',
#   'line',
#   'front',
#   'empty',
#   'desk',
#   'stay',
#   'classy',
#   'air'],
#  ['united', 'tonight', 'make', 'happy', 'upgrade', 'class'],
#  ['united',
#   'ask',
#   'flight',
#   'attendant',
#   'typical',
#   'compensation',
#   'would',
#   'amp',
#   'say',
#   'might',
#   'get',
#   'free',
#   'unacceptable'],
#  ['yes', 'bag', 'come', 'straight', 'hotel', 'thank', 'guy', 'rock'],
#  ['united',
#   'hi',
#   'fly',
#   'tomorrow',
#   'evening',
#   'expect',
#   'delay',
#   'cancel',
#   'snow',
#   'storm'],
#  ['united',
#   'gate',
#   'staff',
#   'disaster',
#   'overbooked',
#   'volunteer',
#   'boarding',
#   'min',
#   'late',
#   'flight',
#   'try',
#   'figure',
#   'issue'],
#  ['problem', 'link', 'email', 'thanks'],
#  ['gate', 'say', 'hold', 'connection', 'thanks', 'quick', 'response'],
#  ['terminal', 'say', 'board', 'pas'],
#  ['charge', 'flight', 'cancel', 'unbelievable', 'unheard'],
#  ['flight',
#   'cancel',
#   'reschedule',
#   'travel',
#   'fund',
#   'put',
#   'back',
#   'account',
#   'future',
#   'use'],
#  ['match', 'status', 'cool'],
#  ['one', 'flt', 'per', 'day'],
#  ['yeah', 'lot', 'question', 'number', 'one', 'dare'],
#  ['thank',
#   'know',
#   'ya',
#   'ca',
#   'control',
#   'weather',
#   'appreciate',
#   'ya',
#   'work',
#   'get',
#   'flight',
#   'last',
#   'two',
#   'day'],
#  ['ca', 'phone', 'break', 'would', 'rather', 'change', 'late'],
#  ['united',
#   'service',
#   'far',
#   'horrid',
#   'want',
#   'end',
#   'trip',
#   'high',
#   'note',
#   'guess',
#   'option'],
#  ['united',
#   'flight',
#   'frustration',
#   'boil',
#   'deal',
#   'attendant',
#   'attitude',
#   'ridiculous'],
#  ['family', 'excite', 'see'],
#  ['united',
#   'customer',
#   'service',
#   'delay',
#   'coupon',
#   'redeem',
#   'website',
#   'high',
#   'price',
#   'call',
#   'wait',
#   'time'],
#  ['united', 'thanks', 'keep', 'good', 'work'],
#  ['temporary',
#   'site',
#   'glitch',
#   'longer',
#   'offer',
#   'flight',
#   'ca',
#   'find',
#   'online'],
#  ['complete', 'case', 'still', 'say', 'progress', 'website', 'reserve'],
#  ['wife',
#   'pt',
#   'expire',
#   'day',
#   'ago',
#   'plan',
#   'flight',
#   'booking',
#   'problem',
#   'trip',
#   'today',
#   'anything',
#   'tight',
#   'budget'],
#  ['hold',
#   'minute',
#   'try',
#   'rebook',
#   'cancelled',
#   'flight',
#   'companion',
#   'ticket',
#   'help'],
#  ['bad', 'experience', 'time', 'never', 'ever', 'ever', 'travel', 'ever'],
#  ['go',
#   'check',
#   'flight',
#   'hr',
#   'advance',
#   'husband',
#   'seat',
#   'separately',
#   'flight',
#   'happen'],
#  ['yea', 'give', 'cent', 'dollar'],
#  ['second', 'pic'],
#  ['thank'],
#  ['united', 'thanks'],
#  ['united', 'okay', 'thanks'],
#  ['really',
#   'appreciate',
#   'great',
#   'customer',
#   'service',
#   'one',
#   'service',
#   'agent',
#   'hang',
#   'ask',
#   'legitimate',
#   'question'],
#  ['still', 'hear', 'thing'],
#  ['chariot', 'tonight', 'angle', 'look', 'like'],
#  ['let', 'plane', 'please', 'go', 'gate', 'absurd'],
#  ['sorry', 'specify', 'mean', 'ground', 'traffic', 'try', 'get', 'terminal'],
#  ['air', 'point', 'combine'],
#  ['hold', 'reservation', 'min', 'already'],
#  ['contact', 'miss', 'rapid', 'reward', 'credit'],
#  ['poop', 'barely', 'work'],
#  ['still',
#   'rep',
#   'talk',
#   'day',
#   'late',
#   'ask',
#   'flight',
#   'refund',
#   'request',
#   'deal'],
#  ['know', 'time', 'lane', 'open', 'logan'],
#  ['happen', 'could', 'get', 'home', 'next', 'day'],
#  ['fleet', 'make', 'stop'],
#  ['customer', 'year'],
#  ['extend',
#   'flight',
#   'bereavement',
#   'could',
#   'change',
#   'fee',
#   'drop',
#   'told',
#   'day',
#   'life'],
#  ['app', 'update', 'passbook', 'support', 'via'],
#  ['earlier', 'say', 'fly', 'school', 'trip'],
#  ['unite', 'take', 'screenshot', 'email', 'let', 'dm', 'figure'],
#  ['kidding'],
#  ['flight', 'full'],
#  ['stick',
#   'airport',
#   'hour',
#   'due',
#   'maintenance',
#   'dread',
#   'flight',
#   'back',
#   'home',
#   'disgusting'],
#  ['service', 'promotion', 'moment', 'innovation'],
#  ['unite', 'new', 'delay', 'right'],
#  ['united',
#   'hello',
#   'unite',
#   'take',
#   'care',
#   'call',
#   'center',
#   'city',
#   'office',
#   'terrible',
#   'attitude',
#   'lady',
#   'help'],
#  ['offer', 'service', 'beach', 'new', 'york', 'business', 'review'],
#  ['try',
#   'choose',
#   'seat',
#   'every',
#   'time',
#   'go',
#   'next',
#   'flight',
#   'get',
#   'system',
#   'error'],
#  ['hear',
#   'anyone',
#   'week',
#   'nonstop',
#   'flight',
#   'baggage',
#   'customer',
#   'service'],
#  ['delay',
#   'almost',
#   'hr',
#   'take',
#   'good',
#   'luck',
#   'today',
#   'really',
#   'frustrating'],
#  ['upgrade',
#   'unsure',
#   'ca',
#   'switch',
#   'someone',
#   'around',
#   'call',
#   'hr',
#   'advance',
#   'reason'],
#  ['great', 'thanks'],
#  ['united', 'thank', 'get', 'daughter', 'home', 'cancel', 'flight'],
#  ['united',
#   'yes',
#   'ride',
#   'home',
#   'would',
#   'perfect',
#   'fete',
#   'one',
#   'would',
#   'assume',
#   'possible',
#   'charge',
#   'domestic',
#   'flight',
#   'deplane'],
#  ['totally',
#   'ruined',
#   'birthday',
#   'weekend',
#   'cancelled',
#   'flight',
#   'reason',
#   'offer',
#   'point',
#   'drink',
#   'transport'],
#  ['united',
#   'nope',
#   'need',
#   'little',
#   'red',
#   'stamp',
#   'counter',
#   'check',
#   'wreck',
#   'son'],
#  ['unite', 'referral', 'program', 'explorer', 'card'],
#  ['guy', 'fail', 'need', 'use', 'voucher', 'ticket', 'ca', 'online'],
#  ['look',
#   'like',
#   'yr',
#   'trip',
#   'replace',
#   'someone',
#   'itinerary',
#   'worried',
#   'flight'],
#  ['thanks', 'finally', 'let', 'get', 'book', 'flight', 'frustration', 'set'],
#  ['unite', 'take', 'one', 'window', 'also', 'fun', 'get', 'motion', 'sick'],
#  ['keep', 'get', 'well', 'water', 'plane'],
#  ['thank', 'hopefully', 'soon', 'suppose', 'leave'],
#  ['united',
#   'thank',
#   'amazing',
#   'airline',
#   'know',
#   'treat',
#   'customer',
#   'guy',
#   'rock'],
#  ['send', 'look', 'functionality', 'app', 'though', 'one', 'click', 'action'],
#  ['need',
#   'help',
#   'record',
#   'locator',
#   'bring',
#   'two',
#   'different',
#   'flight',
#   'system',
#   'one',
#   'op',
#   'aa',
#   'amp',
#   'one',
#   'airway'],
#  ['okay', 'actually', 'tea', 'kinda', 'guy', 'anyway', 'thanks'],
#  ['united',
#   'hold',
#   'almost',
#   'minute',
#   'promise',
#   'free',
#   'movie',
#   'work',
#   'neither',
#   'pay',
#   'boo'],
#  ['baggage', 'handler', 'call', 'today', 'luggage', 'plane'],
#  ['would', 'go', 'though', 'entire', 'process', 'get', 'people', 'phone'],
#  ['crazy', 'treated', 'mom', 'poorly', 'happy'],
#  ['many', 'leave'],
#  ['work',
#   'hard',
#   'make',
#   'sure',
#   'thing',
#   'flow',
#   'smoothly',
#   'keep',
#   'positive'],
#  ['blame',
#   'weather',
#   'rep',
#   'counter',
#   'cost',
#   'entire',
#   'day',
#   'weather',
#   'print',
#   'boarding',
#   'pas',
#   'late',
#   'flight'],
#  ['united', 'thanks', 'update', 'hour', 'delay', 'exact', 'second', 'get'],
#  ['united',
#   'consider',
#   'time',
#   'arrive',
#   'destination',
#   'half',
#   'hour',
#   'late',
#   'schedule'],
#  ['get', 'notify', 'cancel'],
#  ['sp', 'today', 'tremendous', 'help', 'tough', 'situation'],
#  ['united', 'luggage', 'employee', 'tell', 'include', 'wheel', 'dimension'],
#  ['united', 'minute', 'hold', 'hr', 'min'],
#  ['guy', 'screw', 'trip', 'thanks', 'nothing', 'lazy'],
#  ['unite',
#   'passenger',
#   'wait',
#   'inside',
#   'flight',
#   'runway',
#   'return',
#   'back',
#   'gate',
#   'count',
#   'valid',
#   'journey'],
#  ['frustrating',
#   'day',
#   'flight',
#   'home',
#   'change',
#   'airline',
#   'thank',
#   'employee',
#   'amp',
#   'unite',
#   'help',
#   'get',
#   'back'],
#  ['united',
#   'guy',
#   'change',
#   'age',
#   'double',
#   'booked',
#   'seat',
#   'even',
#   'though',
#   'platinum',
#   'person',
#   'none'],
#  ['cancel',
#   'last',
#   'part',
#   'ticket',
#   'confuse',
#   'email',
#   'receive',
#   'whether',
#   'value',
#   'remain',
#   'someone',
#   'ask'],
#  ['united',
#   'business',
#   'decision',
#   'make',
#   'inconvenience',
#   'possibly',
#   'cause',
#   'lost',
#   'customer',
#   'good',
#   'business',
#   'decision',
#   'cranky'],
#  ['flight', 'get', 'cancel', 'charlotte', 'hold', 'hour', 'pick'],
#  ['wow', 'blow', 'mind'],
#  ['time', 'awesome', 'flight', 'great', 'job'],
#  ['realize', 'clothes', 'hotel', 'suggestion'],
#  ['get', 'mine', 'time', 'wife', 'anniversary'],
#  ['must', 'hear', 'wrong', 'sweet', 'though', 'record', 'leave', 'leave'],
#  ['sit',
#   'gate',
#   'flight',
#   'hour',
#   'due',
#   'sabre',
#   'backup',
#   'plan',
#   'place',
#   'sabre',
#   'fix'],
#  ['favorite', 'airline', 'never', 'issue', 'plus', 'crew', 'entertain'],
#  ['make', 'thanks', 'help'],
#  ['utterly', 'unreliable', 'schedule', 'pilot', 'flight', 'flight', 'delay'],
#  ['tremendous',
#   'job',
#   'airport',
#   'saw',
#   'celebrate',
#   'another',
#   'reason',
#   'nut',
#   'guy'],
#  ['united',
#   'seem',
#   'like',
#   'one',
#   'unite',
#   'help',
#   'lot',
#   'finger',
#   'point',
#   'zero',
#   'people',
#   'step',
#   'least',
#   'gate'],
#  ['conf', 'thanks', 'reply'],
#  ['united',
#   'hour',
#   'original',
#   'flight',
#   'say',
#   'handling',
#   'situation',
#   'bad',
#   'would',
#   'understatement'],
#  ['flight', 'leave', 'right', 'try', 'figure', 'delayed', 'flight', 'go'],
#  ['one', 'heck', 'airline'],
#  ['fly',
#   'flight',
#   'tonight',
#   'board',
#   'position',
#   'overbooked',
#   'really',
#   'want',
#   'bump'],
#  ['client',
#   'get',
#   'zero',
#   'year',
#   'career',
#   'never',
#   'think',
#   'suitcase',
#   'worth',
#   'thousand',
#   'clothing',
#   'robbed'],
#  ['cancel', 'flight', 'pay', 'hotel'],
#  ['response',
#   'incredible',
#   'truly',
#   'amaze',
#   'step',
#   'take',
#   'enhance',
#   'customer',
#   'relation',
#   'big',
#   'thank'],
#  ['wow',
#   'tell',
#   'ca',
#   'file',
#   'request',
#   'lost',
#   'bag',
#   'statement',
#   'finish',
#   'travel',
#   'get',
#   'dc'],
#  ['united', 'since', 'international', 'connection', 'hop', 'thing'],
#  ['day'],
#  ['united', 'long', 'take', 'mile', 'expire', 'show', 'email', 'request'],
#  ['unite',
#   'probably',
#   'least',
#   'satisfactory',
#   'airline',
#   'ever',
#   'never',
#   'fail',
#   'disappoint'],
#  ['united', 'airline', 'change', 'program', 'winner', 'loser'],
#  ['aa', 'joke', 'right', 'line', 'even', 'accept', 'call', 'right', 'hang'],
#  ['united', 'nonrefundable', 'hence', 'write', 'make', 'sense', 'credit'],
#  ['even', 'year', 'earthquake', 'still', 'need', 'help', 'rebuild'],
#  ['despite',
#   'mechanical',
#   'issue',
#   'many',
#   'delay',
#   'follow',
#   'cancelled',
#   'still',
#   'get',
#   'thanks',
#   'great',
#   'gate',
#   'agent'],
#  ['excuse', 'though', 'gate', 'change', 'though'],
#  ['may', 'need', 'minute', 'layover', 'min', 'delay', 'first', 'flight'],
#  ['united', 'get', 'reimburse', 'hotel', 'taxi', 'cancelled'],
#  ['yet',
#   'receive',
#   'assistance',
#   'one',
#   'agent',
#   'secure',
#   'new',
#   'connection',
#   'many',
#   'miss',
#   'work',
#   'tomorrow'],
#  ['three', 'hour', 'flight', 'delay', 'phone', 'counting'],
#  ['everyone', 'else', 'outstanding'],
#  ['unite',
#   'think',
#   'rough',
#   'moment',
#   'bad',
#   'passenger',
#   'early',
#   'flight',
#   'thing',
#   'get',
#   'considerably',
#   'well',
#   'thanks'],
#  ['thanks'],
#  ['cancel', 'ticket', 'take', 'two', 'month', 'refund', 'still', 'wait'],
#  [],
#  ['shout',
#   'pilot',
#   'attendant',
#   'super',
#   'strong',
#   'crosswind',
#   'landing',
#   'super',
#   'job',
#   'throughout'],
#  ['unite', 'see', 'come', 'get'],
#  ['together', 'best', 'part', 'fly'],
#  ['united',
#   'late',
#   'flight',
#   'future',
#   'flight',
#   'train',
#   'staff',
#   'well',
#   'handle',
#   'emergency',
#   'situation',
#   'ground',
#   'staff',
#   'customer',
#   'service'],
#  ['united', 'oh', 'unite', 'much', 'despise', 'thee'],
#  ['united', 'airline', 'disloyal', 'loyal', 'worker', 'via'],
#  ['united',
#   'disappoint',
#   'service',
#   'miss',
#   'connection',
#   'hour',
#   'delay',
#   'cramp',
#   'seat',
#   'least',
#   'app',
#   'good'],
#  ['sit', 'airport', 'long', 'time', 'plane', 'nasty'],
#  ['united', 'flight'],
#  ['united', 'fuck', 'care'],
#  ['info',
#   'winner',
#   'announce',
#   'amp',
#   'best',
#   'friend',
#   'hop',
#   'win',
#   'thanks'],
#  ['thanks'],
#  ['tweet',
#   'bad',
#   'weather',
#   'close',
#   'customer',
#   'relation',
#   'center',
#   'process',
#   'refund',
#   'cancel',
#   'flighted',
#   'flight'],
#  ['miss',
#   'point',
#   'one',
#   'account',
#   'spread',
#   'four',
#   'assume',
#   'create',
#   'account'],
#  ['unite', 'use', 'committed', 'merger', 'remember', 'switch'],
#  ['unite', 'soon', 'do', 'article', 'thanks'],
#  ['find', 'unite', 'airline', 'realize', 'could', 'get', 'home', 'ord'],
#  ['give'],
#  ['ticket',
#   'use',
#   'unable',
#   'get',
#   'depart',
#   'blizzard',
#   'tell',
#   'way',
#   'use',
#   'credit',
#   'fine'],
#  ...]

# %%
x_train = []
x_test = []
for i in range (0, len(train_data)):
    x_train.append(' '.join(train_data[i]))
for i in range (0, len(test_data)):
    x_test.append(' '.join(test_data[i]))

# %% [markdown]
# We use TfidVectorizer in place of Count vectorizer as it gives much better accuracy

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

count_vec = TfidfVectorizer(stop_words= stop, max_df=0.95, min_df=0.001) 
x_train = count_vec.fit_transform(x_train)

# %%
x_train
# Out:
# <10980x1011 sparse matrix of type '<class 'numpy.float64'>'
# 	with 72237 stored elements in Compressed Sparse Row format>

# %%
x_test = count_vec.transform(x_test)

# %%
x_test
# Out:
# <3660x1011 sparse matrix of type '<class 'numpy.float64'>'
# 	with 23845 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Now we use the different pre built models to find the one with highest accuracy

# %% [markdown]
# RANDOM FOREST

# %%
### RANDOM FOREST

from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
clf.fit(x_train, y_train)

y_test=clf.predict(x_test)

np.savetxt('RandomForest.csv',y_test,delimiter = ',',fmt='%s')

# %% [markdown]
# Descision Tree

# %%
### Descision Tree
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)

y_test = clf.predict(x_test)

np.savetxt('DescisionTree.csv',y_test,delimiter = ',',fmt='%s')

# %% [markdown]
# Multinomial Naive Bayes

# %%
### Multinomial Naive Bayes
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB(alpha = 1)
clf.fit(x_train, y_train)

y_test = clf.predict(x_test)

np.savetxt('MNaiveBayes.csv',y_test,delimiter = ',',fmt='%s')

# %% [markdown]
# Support Vector Machine

# %%
### SVM
from sklearn.svm import SVC

clf = SVC()
clf.fit(x_train, y_train)

y_test = clf.predict(x_test)

np.savetxt('SVM.csv',y_test,delimiter = ',',fmt='%s')

# %% [markdown]
# Logistic Regression

# %%
### Logistic Regression
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(x_train, y_train)

y_test = clf.predict(x_test)
np.savetxt('LogisticRegression.csv',y_test,delimiter = ',',fmt='%s')

# %% [markdown]
# The predicted values were tested on Coding Ninjas website and the highest accuracy was obtained by Logistic Regression and SVM models crossing 77%, Multinomial Naive Bayes and Random Forest both had accuracy around 75% and Descision Tree had accuracy nearing 70%
